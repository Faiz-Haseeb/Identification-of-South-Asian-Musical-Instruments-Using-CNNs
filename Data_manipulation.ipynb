# %%
#Importing audio segmenting library
from pydub import AudioSegment
import os
# Out:
# c:\Users\Faiz_\AppData\Local\Programs\Python\Python39\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %% [markdown]
# ### Splitting audio file into 4 second segments

# %%
from pydub import AudioSegment


# Directory to store clips
output_folder = "sitar-tabla-harmonium-bansuri"

# Ensure the output folder exists, or create it if it doesn't
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# List existing clip files to determine the next clip number
existing_clips = os.listdir(output_folder)
clip_number =  len(existing_clips)  # Set the clip number to the next available number

# Load the audio file
audio = AudioSegment.from_file("sitar-tabla-harmonium-bansuri.wav", format="wav")

# Split into 4-second clips
clip_length = 4 * 1000  # 4 seconds in milliseconds

for start_time in range(0, len(audio), clip_length):
    clip = audio[start_time:start_time + clip_length]
    clip.export(f"{output_folder}/clip_{clip_number}.wav", format="wav")
    clip_number += 1  # Increment the clip number for the next clip

# %% [markdown]
# ### Reordering the clips in a folder

# %%
def reorder_files(folder_path, start_number):
    # Get a list of all files in the folder
    files = os.listdir(folder_path)

    # Filter only files (not directories)
    files = [file for file in files if os.path.isfile(os.path.join(folder_path, file))]

    # Sort files to ensure consistent numbering
    files.sort()

    # Rename the files in the folder with sequential numbers
    for i, file_name in enumerate(files, start=start_number):
        new_name = f"clip-{i}.wav"
        new_name = f"clip_{i}.wav"
        current_path = os.path.join(folder_path, file_name)
        new_path = os.path.join(folder_path, new_name)
        os.rename(current_path, new_path)

# Replace "folder_path" with the path to your folder
folder_path = "output-tabla-harmonium"

# Replace "start_number" with the desired starting number
start_number = 111

# Reorder the files in the folder
reorder_files(folder_path, start_number)

# %% [markdown]
# ### Combining audio files for 2 different classes

# %%
# Replace these paths with the actual paths to your folders
folder_1_path = "harmonium-combo"
folder_2_path = "bansuri-combo"

# Set the output folder
output_folder = "harmonium-bansuri"

# Iterate through each pair of audio clips in the folders
for i in range(1, 35):  # Assuming your files are named clip_1.wav, clip_2.wav, ..., clip_700.wav
    # Load the audio clips
    audio_1 = AudioSegment.from_file(f"{folder_1_path}/clip_{i}.wav", format="wav")
    audio_2 = AudioSegment.from_file(f"{folder_2_path}/clip_{i}.wav", format="wav")

    # Ensure both audio clips have the same duration (adjust if needed)
    min_length = min(len(audio_1), len(audio_2))
    audio_1 = audio_1[:min_length]
    audio_2 = audio_2[:min_length]

    # Set the duration of each overlap (1 second in this case)
    overlap_duration = 1000  # in milliseconds

    # Initialize the combined audio with the first second of the first clip
    combined_audio = audio_1[:overlap_duration]

    # Iterate over the remaining seconds and overlap the clips
    for t in range(overlap_duration, min_length, overlap_duration):
        combined_audio = combined_audio.append(audio_1[t:t + overlap_duration].overlay(audio_2[t:t + overlap_duration]))

    # Export the combined audio clip
    combined_audio.export(f"{output_folder}/clip_{i}.wav", format="wav")
# Out:
# Processing files: clip_0.wav and clip_0.wav
# Processing files: clip_1.wav and clip_1.wav
# Processing files: clip_10.wav and clip_10.wav
# Processing files: clip_100.wav and clip_100.wav
# Processing files: clip_1000.wav and clip_101.wav
# Processing files: clip_1001.wav and clip_102.wav
# Processing files: clip_1002.wav and clip_103.wav
# Processing files: clip_1003.wav and clip_104.wav
# Processing files: clip_1004.wav and clip_105.wav
# Processing files: clip_1005.wav and clip_106.wav
# Processing files: clip_1006.wav and clip_107.wav
# Processing files: clip_1007.wav and clip_108.wav
# Processing files: clip_1008.wav and clip_109.wav
# Processing files: clip_1009.wav and clip_11.wav
# Processing files: clip_101.wav and clip_110.wav
# Processing files: clip_1010.wav and clip_111.wav
# Processing files: clip_1011.wav and clip_112.wav
# Processing files: clip_1012.wav and clip_113.wav
# Processing files: clip_1013.wav and clip_114.wav
# Processing files: clip_1014.wav and clip_115.wav
# Processing files: clip_1015.wav and clip_116.wav
# Processing files: clip_1016.wav and clip_117.wav
# Processing files: clip_1017.wav and clip_118.wav
# Processing files: clip_1018.wav and clip_119.wav
# Processing files: clip_1019.wav and clip_12.wav
# Processing files: clip_102.wav and clip_120.wav
# Processing files: clip_1020.wav and clip_121.wav
# Processing files: clip_1021.wav and clip_122.wav
# Processing files: clip_1022.wav and clip_123.wav
# Processing files: clip_1023.wav and clip_124.wav
# Processing files: clip_1024.wav and clip_125.wav
# Processing files: clip_1025.wav and clip_126.wav
# Processing files: clip_1026.wav and clip_127.wav
# Processing files: clip_1027.wav and clip_128.wav
# Processing files: clip_1028.wav and clip_129.wav
# Processing files: clip_1029.wav and clip_13.wav
# Processing files: clip_103.wav and clip_130.wav
# Processing files: clip_1030.wav and clip_131.wav
# Processing files: clip_1031.wav and clip_132.wav
# Processing files: clip_1032.wav and clip_133.wav
# Processing files: clip_1033.wav and clip_134.wav
# Processing files: clip_1034.wav and clip_135.wav
# Processing files: clip_1035.wav and clip_136.wav
# Processing files: clip_1036.wav and clip_137.wav
# Processing files: clip_1037.wav and clip_138.wav
# Processing files: clip_1038.wav and clip_139.wav
# Processing files: clip_1039.wav and clip_14.wav
# Processing files: clip_104.wav and clip_140.wav
# Processing files: clip_1040.wav and clip_141.wav
# Processing files: clip_1041.wav and clip_142.wav
# Processing files: clip_1042.wav and clip_143.wav
# Processing files: clip_1043.wav and clip_144.wav
# Processing files: clip_105.wav and clip_145.wav
# Processing files: clip_106.wav and clip_146.wav
# Processing files: clip_107.wav and clip_147.wav
# Processing files: clip_108.wav and clip_148.wav
# Processing files: clip_109.wav and clip_149.wav
# Processing files: clip_11.wav and clip_15.wav
# Processing files: clip_110.wav and clip_150.wav
# Processing files: clip_111.wav and clip_151.wav
# Processing files: clip_112.wav and clip_152.wav
# Processing files: clip_113.wav and clip_153.wav
# Processing files: clip_114.wav and clip_154.wav
# Processing files: clip_115.wav and clip_155.wav
# Processing files: clip_116.wav and clip_156.wav
# Processing files: clip_117.wav and clip_157.wav
# Processing files: clip_118.wav and clip_158.wav
# Processing files: clip_119.wav and clip_159.wav
# Processing files: clip_12.wav and clip_16.wav
# Processing files: clip_120.wav and clip_160.wav
# Processing files: clip_121.wav and clip_161.wav
# Processing files: clip_122.wav and clip_162.wav
# Processing files: clip_123.wav and clip_163.wav
# Processing files: clip_124.wav and clip_164.wav
# Processing files: clip_125.wav and clip_165.wav
# Processing files: clip_126.wav and clip_166.wav
# Processing files: clip_127.wav and clip_167.wav
# Processing files: clip_128.wav and clip_168.wav
# Processing files: clip_129.wav and clip_169.wav
# Processing files: clip_13.wav and clip_17.wav
# Processing files: clip_130.wav and clip_170.wav
# Processing files: clip_131.wav and clip_171.wav
# Processing files: clip_132.wav and clip_172.wav
# Processing files: clip_133.wav and clip_173.wav
# Processing files: clip_134.wav and clip_174.wav
# Processing files: clip_135.wav and clip_175.wav
# Processing files: clip_136.wav and clip_176.wav
# Processing files: clip_137.wav and clip_177.wav
# Processing files: clip_138.wav and clip_178.wav
# Processing files: clip_139.wav and clip_179.wav
# Processing files: clip_14.wav and clip_18.wav
# Processing files: clip_140.wav and clip_180.wav
# Processing files: clip_141.wav and clip_181.wav
# Processing files: clip_142.wav and clip_182.wav
# Processing files: clip_143.wav and clip_183.wav
# Processing files: clip_144.wav and clip_184.wav
# Processing files: clip_145.wav and clip_185.wav
# Processing files: clip_146.wav and clip_186.wav
# Processing files: clip_147.wav and clip_187.wav
# Processing files: clip_148.wav and clip_188.wav
# Processing files: clip_149.wav and clip_189.wav
# Processing files: clip_15.wav and clip_19.wav
# Processing files: clip_150.wav and clip_190.wav
# Processing files: clip_151.wav and clip_191.wav
# Processing files: clip_152.wav and clip_192.wav
# Processing files: clip_153.wav and clip_193.wav
# Processing files: clip_154.wav and clip_194.wav
# Processing files: clip_155.wav and clip_195.wav
# Processing files: clip_156.wav and clip_196.wav
# Processing files: clip_157.wav and clip_197.wav
# Processing files: clip_158.wav and clip_198.wav
# Processing files: clip_159.wav and clip_199.wav
# Processing files: clip_16.wav and clip_2.wav
# Processing files: clip_160.wav and clip_20.wav
# Processing files: clip_161.wav and clip_200.wav
# Processing files: clip_162.wav and clip_201.wav
# Processing files: clip_163.wav and clip_202.wav
# Processing files: clip_164.wav and clip_203.wav
# Processing files: clip_165.wav and clip_204.wav
# Processing files: clip_166.wav and clip_205.wav
# Processing files: clip_167.wav and clip_206.wav
# Processing files: clip_168.wav and clip_207.wav
# Processing files: clip_169.wav and clip_208.wav
# Processing files: clip_17.wav and clip_209.wav
# Processing files: clip_170.wav and clip_21.wav
# Processing files: clip_171.wav and clip_210.wav
# Processing files: clip_172.wav and clip_211.wav
# Processing files: clip_173.wav and clip_212.wav
# Processing files: clip_174.wav and clip_213.wav
# Processing files: clip_175.wav and clip_214.wav
# Processing files: clip_176.wav and clip_215.wav
# Processing files: clip_177.wav and clip_216.wav
# Processing files: clip_178.wav and clip_217.wav
# Processing files: clip_179.wav and clip_218.wav
# Processing files: clip_18.wav and clip_219.wav
# Processing files: clip_180.wav and clip_22.wav
# Processing files: clip_181.wav and clip_220.wav
# Processing files: clip_182.wav and clip_221.wav
# Processing files: clip_183.wav and clip_222.wav
# Processing files: clip_184.wav and clip_223.wav
# Processing files: clip_185.wav and clip_224.wav
# Processing files: clip_186.wav and clip_225.wav
# Processing files: clip_187.wav and clip_226.wav
# Processing files: clip_188.wav and clip_227.wav
# Processing files: clip_189.wav and clip_228.wav
# Processing files: clip_19.wav and clip_229.wav
# Processing files: clip_190.wav and clip_23.wav
# Processing files: clip_191.wav and clip_230.wav
# Processing files: clip_192.wav and clip_231.wav
# Processing files: clip_193.wav and clip_232.wav
# Processing files: clip_194.wav and clip_233.wav
# Processing files: clip_195.wav and clip_234.wav
# Processing files: clip_196.wav and clip_235.wav
# Processing files: clip_197.wav and clip_236.wav
# Processing files: clip_198.wav and clip_237.wav
# Processing files: clip_199.wav and clip_238.wav
# Processing files: clip_2.wav and clip_239.wav
# Processing files: clip_20.wav and clip_24.wav
# Processing files: clip_200.wav and clip_240.wav
# Processing files: clip_201.wav and clip_241.wav
# Processing files: clip_202.wav and clip_242.wav
# Processing files: clip_203.wav and clip_243.wav
# Processing files: clip_204.wav and clip_244.wav
# Processing files: clip_205.wav and clip_245.wav
# Processing files: clip_206.wav and clip_246.wav
# Processing files: clip_207.wav and clip_247.wav
# Processing files: clip_208.wav and clip_248.wav
# Processing files: clip_209.wav and clip_249.wav
# Processing files: clip_21.wav and clip_25.wav
# Processing files: clip_210.wav and clip_250.wav
# Processing files: clip_211.wav and clip_251.wav
# Processing files: clip_212.wav and clip_252.wav
# Processing files: clip_213.wav and clip_253.wav
# Processing files: clip_214.wav and clip_254.wav
# Processing files: clip_215.wav and clip_255.wav
# Processing files: clip_216.wav and clip_256.wav
# Processing files: clip_217.wav and clip_257.wav
# Processing files: clip_218.wav and clip_258.wav
# Processing files: clip_219.wav and clip_259.wav
# Processing files: clip_22.wav and clip_26.wav
# Processing files: clip_220.wav and clip_260.wav
# Processing files: clip_221.wav and clip_261.wav
# Processing files: clip_222.wav and clip_262.wav
# Processing files: clip_223.wav and clip_263.wav
# Processing files: clip_224.wav and clip_264.wav
# Processing files: clip_225.wav and clip_265.wav
# Processing files: clip_226.wav and clip_266.wav
# Processing files: clip_227.wav and clip_267.wav
# Processing files: clip_228.wav and clip_268.wav
# Processing files: clip_229.wav and clip_269.wav
# Processing files: clip_23.wav and clip_27.wav
# Processing files: clip_230.wav and clip_270.wav
# Processing files: clip_231.wav and clip_271.wav
# Processing files: clip_232.wav and clip_272.wav
# Processing files: clip_233.wav and clip_273.wav
# Processing files: clip_234.wav and clip_274.wav
# Processing files: clip_235.wav and clip_275.wav
# Processing files: clip_236.wav and clip_276.wav
# Processing files: clip_237.wav and clip_277.wav
# Processing files: clip_238.wav and clip_278.wav
# Processing files: clip_239.wav and clip_279.wav
# Processing files: clip_24.wav and clip_28.wav
# Processing files: clip_240.wav and clip_280.wav
# Processing files: clip_241.wav and clip_281.wav
# Processing files: clip_242.wav and clip_282.wav
# Processing files: clip_243.wav and clip_283.wav
# Processing files: clip_244.wav and clip_284.wav
# Processing files: clip_245.wav and clip_285.wav
# Processing files: clip_246.wav and clip_286.wav
# Processing files: clip_247.wav and clip_287.wav
# Processing files: clip_248.wav and clip_288.wav
# Processing files: clip_249.wav and clip_289.wav
# Processing files: clip_25.wav and clip_29.wav
# Processing files: clip_250.wav and clip_290.wav
# Processing files: clip_251.wav and clip_291.wav
# Processing files: clip_252.wav and clip_292.wav
# Processing files: clip_253.wav and clip_293.wav
# Processing files: clip_254.wav and clip_294.wav
# Processing files: clip_255.wav and clip_295.wav
# Processing files: clip_256.wav and clip_296.wav
# Processing files: clip_257.wav and clip_297.wav
# Processing files: clip_258.wav and clip_298.wav
# Processing files: clip_259.wav and clip_299.wav
# Processing files: clip_26.wav and clip_3.wav
# Processing files: clip_260.wav and clip_30.wav
# Processing files: clip_261.wav and clip_300.wav
# Processing files: clip_262.wav and clip_301.wav
# Processing files: clip_263.wav and clip_302.wav
# Processing files: clip_264.wav and clip_303.wav
# Processing files: clip_265.wav and clip_304.wav
# Processing files: clip_266.wav and clip_305.wav
# Processing files: clip_267.wav and clip_306.wav
# Processing files: clip_268.wav and clip_307.wav
# Processing files: clip_269.wav and clip_308.wav
# Processing files: clip_27.wav and clip_309.wav
# Processing files: clip_270.wav and clip_31.wav
# Processing files: clip_271.wav and clip_310.wav
# Processing files: clip_272.wav and clip_311.wav
# Processing files: clip_273.wav and clip_312.wav
# Processing files: clip_274.wav and clip_313.wav
# Processing files: clip_275.wav and clip_314.wav
# Processing files: clip_276.wav and clip_315.wav
# Processing files: clip_277.wav and clip_316.wav
# Processing files: clip_278.wav and clip_317.wav
# Processing files: clip_279.wav and clip_318.wav
# Processing files: clip_28.wav and clip_319.wav
# Processing files: clip_280.wav and clip_32.wav
# Processing files: clip_281.wav and clip_320.wav
# Processing files: clip_282.wav and clip_321.wav
# Processing files: clip_283.wav and clip_322.wav
# Processing files: clip_284.wav and clip_323.wav
# Processing files: clip_285.wav and clip_324.wav
# Processing files: clip_286.wav and clip_325.wav
# Processing files: clip_287.wav and clip_326.wav
# Processing files: clip_288.wav and clip_327.wav
# Processing files: clip_289.wav and clip_328.wav
# Processing files: clip_29.wav and clip_329.wav
# Processing files: clip_290.wav and clip_33.wav
# Processing files: clip_291.wav and clip_330.wav
# Processing files: clip_292.wav and clip_331.wav
# Processing files: clip_293.wav and clip_332.wav
# Processing files: clip_294.wav and clip_333.wav
# Processing files: clip_295.wav and clip_334.wav
# Processing files: clip_296.wav and clip_335.wav
# Processing files: clip_297.wav and clip_336.wav
# Processing files: clip_298.wav and clip_337.wav
# Processing files: clip_299.wav and clip_338.wav
# Processing files: clip_3.wav and clip_339.wav
# Processing files: clip_30.wav and clip_34.wav
# Processing files: clip_300.wav and clip_340.wav
# Processing files: clip_301.wav and clip_341.wav
# Processing files: clip_302.wav and clip_342.wav
# Processing files: clip_303.wav and clip_343.wav
# Processing files: clip_304.wav and clip_344.wav
# Processing files: clip_305.wav and clip_345.wav
# Processing files: clip_306.wav and clip_346.wav
# Processing files: clip_307.wav and clip_347.wav
# Processing files: clip_308.wav and clip_348.wav
# Processing files: clip_309.wav and clip_349.wav
# Processing files: clip_31.wav and clip_35.wav
# Processing files: clip_310.wav and clip_350.wav
# Processing files: clip_311.wav and clip_351.wav
# Processing files: clip_312.wav and clip_352.wav
# Processing files: clip_313.wav and clip_353.wav
# Processing files: clip_314.wav and clip_354.wav
# Processing files: clip_315.wav and clip_355.wav
# Processing files: clip_316.wav and clip_356.wav
# Processing files: clip_317.wav and clip_357.wav
# Processing files: clip_318.wav and clip_358.wav
# Processing files: clip_319.wav and clip_359.wav
# Processing files: clip_32.wav and clip_36.wav
# Processing files: clip_320.wav and clip_360.wav
# Processing files: clip_321.wav and clip_361.wav
# Processing files: clip_322.wav and clip_362.wav
# Processing files: clip_323.wav and clip_363.wav
# Processing files: clip_324.wav and clip_364.wav
# Processing files: clip_325.wav and clip_365.wav
# Processing files: clip_326.wav and clip_366.wav
# Processing files: clip_327.wav and clip_367.wav
# Processing files: clip_328.wav and clip_368.wav
# Processing files: clip_329.wav and clip_369.wav
# Processing files: clip_33.wav and clip_37.wav
# Processing files: clip_330.wav and clip_370.wav
# Processing files: clip_331.wav and clip_371.wav
# Processing files: clip_332.wav and clip_372.wav
# Processing files: clip_333.wav and clip_373.wav
# Processing files: clip_334.wav and clip_374.wav
# Processing files: clip_335.wav and clip_375.wav
# Processing files: clip_336.wav and clip_376.wav
# Processing files: clip_337.wav and clip_377.wav
# Processing files: clip_338.wav and clip_378.wav
# Processing files: clip_339.wav and clip_379.wav
# Processing files: clip_34.wav and clip_38.wav
# Processing files: clip_340.wav and clip_380.wav
# Processing files: clip_341.wav and clip_381.wav
# Processing files: clip_342.wav and clip_382.wav
# Processing files: clip_343.wav and clip_383.wav
# Processing files: clip_344.wav and clip_384.wav
# Processing files: clip_345.wav and clip_385.wav
# Processing files: clip_346.wav and clip_386.wav
# Processing files: clip_347.wav and clip_387.wav
# Processing files: clip_348.wav and clip_388.wav
# Processing files: clip_349.wav and clip_389.wav
# Processing files: clip_35.wav and clip_39.wav
# Processing files: clip_350.wav and clip_390.wav
# Processing files: clip_351.wav and clip_391.wav
# Processing files: clip_352.wav and clip_392.wav
# Processing files: clip_353.wav and clip_393.wav
# Processing files: clip_354.wav and clip_394.wav
# Processing files: clip_355.wav and clip_395.wav
# Processing files: clip_356.wav and clip_396.wav
# Processing files: clip_357.wav and clip_397.wav
# Processing files: clip_358.wav and clip_398.wav
# Processing files: clip_359.wav and clip_399.wav
# Processing files: clip_36.wav and clip_4.wav
# Processing files: clip_360.wav and clip_40.wav
# Processing files: clip_361.wav and clip_400.wav
# Processing files: clip_362.wav and clip_401.wav
# Processing files: clip_363.wav and clip_402.wav
# Processing files: clip_364.wav and clip_403.wav
# Processing files: clip_365.wav and clip_404.wav
# Processing files: clip_366.wav and clip_405.wav
# Processing files: clip_367.wav and clip_406.wav
# Processing files: clip_368.wav and clip_407.wav
# Processing files: clip_369.wav and clip_408.wav
# Processing files: clip_37.wav and clip_409.wav
# Processing files: clip_370.wav and clip_41.wav
# Processing files: clip_371.wav and clip_410.wav
# Processing files: clip_372.wav and clip_411.wav
# Processing files: clip_373.wav and clip_412.wav
# Processing files: clip_374.wav and clip_413.wav
# Processing files: clip_375.wav and clip_414.wav
# Processing files: clip_376.wav and clip_415.wav
# Processing files: clip_377.wav and clip_416.wav
# Processing files: clip_378.wav and clip_417.wav
# Processing files: clip_379.wav and clip_418.wav
# Processing files: clip_38.wav and clip_419.wav
# Processing files: clip_380.wav and clip_42.wav
# Processing files: clip_381.wav and clip_420.wav
# Processing files: clip_382.wav and clip_421.wav
# Processing files: clip_383.wav and clip_422.wav
# Processing files: clip_384.wav and clip_423.wav
# Processing files: clip_385.wav and clip_424.wav
# Processing files: clip_386.wav and clip_425.wav
# Processing files: clip_387.wav and clip_426.wav
# Processing files: clip_388.wav and clip_427.wav
# Processing files: clip_389.wav and clip_428.wav
# Processing files: clip_39.wav and clip_429.wav
# Processing files: clip_390.wav and clip_43.wav
# Processing files: clip_391.wav and clip_430.wav
# Processing files: clip_392.wav and clip_431.wav
# Processing files: clip_393.wav and clip_432.wav
# Processing files: clip_394.wav and clip_433.wav
# Processing files: clip_395.wav and clip_434.wav
# Processing files: clip_396.wav and clip_435.wav
# Processing files: clip_397.wav and clip_436.wav
# Processing files: clip_398.wav and clip_437.wav
# Processing files: clip_399.wav and clip_438.wav
# Processing files: clip_4.wav and clip_439.wav
# Processing files: clip_40.wav and clip_44.wav
# Processing files: clip_400.wav and clip_440.wav
# Processing files: clip_401.wav and clip_441.wav
# Processing files: clip_402.wav and clip_442.wav
# Processing files: clip_403.wav and clip_443.wav
# Processing files: clip_404.wav and clip_444.wav
# Processing files: clip_405.wav and clip_445.wav
# Processing files: clip_406.wav and clip_446.wav
# Processing files: clip_407.wav and clip_447.wav
# Processing files: clip_408.wav and clip_448.wav
# Processing files: clip_409.wav and clip_449.wav
# Processing files: clip_41.wav and clip_45.wav
# Processing files: clip_410.wav and clip_450.wav
# Processing files: clip_411.wav and clip_451.wav
# Processing files: clip_412.wav and clip_452.wav
# Processing files: clip_413.wav and clip_453.wav
# Processing files: clip_414.wav and clip_454.wav
# Processing files: clip_415.wav and clip_455.wav
# Processing files: clip_416.wav and clip_456.wav
# Processing files: clip_417.wav and clip_457.wav
# Processing files: clip_418.wav and clip_458.wav
# Processing files: clip_419.wav and clip_459.wav
# Processing files: clip_42.wav and clip_46.wav
# Processing files: clip_420.wav and clip_460.wav
# Processing files: clip_421.wav and clip_461.wav
# Processing files: clip_422.wav and clip_462.wav
# Processing files: clip_423.wav and clip_463.wav
# Processing files: clip_424.wav and clip_464.wav
# Processing files: clip_425.wav and clip_465.wav
# Processing files: clip_426.wav and clip_466.wav
# Processing files: clip_427.wav and clip_467.wav
# Processing files: clip_428.wav and clip_468.wav
# Processing files: clip_429.wav and clip_469.wav
# Processing files: clip_43.wav and clip_47.wav
# Processing files: clip_430.wav and clip_470.wav
# Processing files: clip_431.wav and clip_471.wav
# Processing files: clip_432.wav and clip_472.wav
# Processing files: clip_433.wav and clip_473.wav
# Processing files: clip_434.wav and clip_474.wav
# Processing files: clip_435.wav and clip_475.wav
# Processing files: clip_436.wav and clip_476.wav
# Processing files: clip_437.wav and clip_477.wav
# Processing files: clip_438.wav and clip_478.wav
# Processing files: clip_439.wav and clip_479.wav
# Processing files: clip_44.wav and clip_48.wav
# Processing files: clip_440.wav and clip_480.wav
# Processing files: clip_441.wav and clip_481.wav
# Processing files: clip_442.wav and clip_482.wav
# Processing files: clip_443.wav and clip_483.wav
# Processing files: clip_444.wav and clip_484.wav
# Processing files: clip_445.wav and clip_485.wav
# Processing files: clip_446.wav and clip_486.wav
# Processing files: clip_447.wav and clip_487.wav
# Processing files: clip_448.wav and clip_488.wav
# Processing files: clip_449.wav and clip_489.wav
# Processing files: clip_45.wav and clip_49.wav
# Processing files: clip_450.wav and clip_490.wav
# Processing files: clip_451.wav and clip_491.wav
# Processing files: clip_452.wav and clip_492.wav
# Processing files: clip_453.wav and clip_493.wav
# Processing files: clip_454.wav and clip_494.wav
# Processing files: clip_455.wav and clip_495.wav
# Processing files: clip_456.wav and clip_496.wav
# Processing files: clip_457.wav and clip_497.wav
# Processing files: clip_458.wav and clip_498.wav
# Processing files: clip_459.wav and clip_499.wav
# Processing files: clip_46.wav and clip_5.wav
# Processing files: clip_460.wav and clip_50.wav
# Processing files: clip_461.wav and clip_500.wav
# Processing files: clip_462.wav and clip_501.wav
# Processing files: clip_463.wav and clip_502.wav
# Processing files: clip_464.wav and clip_503.wav
# Processing files: clip_465.wav and clip_504.wav
# Processing files: clip_466.wav and clip_505.wav
# Processing files: clip_467.wav and clip_506.wav
# Processing files: clip_468.wav and clip_507.wav
# Processing files: clip_469.wav and clip_508.wav
# Processing files: clip_47.wav and clip_509.wav
# Processing files: clip_470.wav and clip_51.wav
# Processing files: clip_471.wav and clip_510.wav
# Processing files: clip_472.wav and clip_511.wav
# Processing files: clip_473.wav and clip_512.wav
# Processing files: clip_474.wav and clip_513.wav
# Processing files: clip_475.wav and clip_514.wav
# Processing files: clip_476.wav and clip_515.wav
# Processing files: clip_477.wav and clip_516.wav
# Processing files: clip_478.wav and clip_517.wav
# Processing files: clip_479.wav and clip_518.wav
# Processing files: clip_48.wav and clip_519.wav
# Processing files: clip_480.wav and clip_52.wav
# Processing files: clip_481.wav and clip_520.wav
# Processing files: clip_482.wav and clip_521.wav
# Processing files: clip_483.wav and clip_522.wav
# Processing files: clip_484.wav and clip_523.wav
# Processing files: clip_485.wav and clip_524.wav
# Processing files: clip_486.wav and clip_525.wav
# Processing files: clip_487.wav and clip_526.wav
# Processing files: clip_488.wav and clip_527.wav
# Processing files: clip_489.wav and clip_528.wav
# Processing files: clip_49.wav and clip_529.wav
# Processing files: clip_490.wav and clip_53.wav
# Processing files: clip_491.wav and clip_530.wav
# Processing files: clip_492.wav and clip_531.wav
# Processing files: clip_493.wav and clip_532.wav
# Processing files: clip_494.wav and clip_533.wav
# Processing files: clip_495.wav and clip_534.wav
# Processing files: clip_496.wav and clip_535.wav
# Processing files: clip_497.wav and clip_536.wav
# Processing files: clip_498.wav and clip_537.wav
# Processing files: clip_499.wav and clip_538.wav
# Processing files: clip_5.wav and clip_539.wav
# Processing files: clip_50.wav and clip_54.wav
# Processing files: clip_500.wav and clip_540.wav
# Processing files: clip_501.wav and clip_541.wav
# Processing files: clip_502.wav and clip_542.wav
# Processing files: clip_503.wav and clip_543.wav
# Processing files: clip_504.wav and clip_544.wav
# Processing files: clip_505.wav and clip_545.wav
# Processing files: clip_506.wav and clip_546.wav
# Processing files: clip_507.wav and clip_547.wav
# Processing files: clip_508.wav and clip_548.wav
# Processing files: clip_509.wav and clip_549.wav
# Processing files: clip_51.wav and clip_55.wav
# Processing files: clip_510.wav and clip_550.wav
# Processing files: clip_511.wav and clip_551.wav
# Processing files: clip_512.wav and clip_552.wav
# Processing files: clip_513.wav and clip_553.wav
# Processing files: clip_514.wav and clip_554.wav
# Processing files: clip_515.wav and clip_555.wav
# Processing files: clip_516.wav and clip_556.wav
# Processing files: clip_517.wav and clip_557.wav
# Processing files: clip_518.wav and clip_558.wav
# Processing files: clip_519.wav and clip_559.wav
# Processing files: clip_52.wav and clip_56.wav
# Processing files: clip_520.wav and clip_560.wav
# Processing files: clip_521.wav and clip_561.wav
# Processing files: clip_522.wav and clip_562.wav
# Processing files: clip_523.wav and clip_563.wav
# Processing files: clip_524.wav and clip_564.wav
# Processing files: clip_525.wav and clip_565.wav
# Processing files: clip_526.wav and clip_566.wav
# Processing files: clip_527.wav and clip_567.wav
# Processing files: clip_528.wav and clip_568.wav
# Processing files: clip_529.wav and clip_569.wav
# Processing files: clip_53.wav and clip_57.wav
# Processing files: clip_530.wav and clip_570.wav
# Processing files: clip_531.wav and clip_571.wav
# Processing files: clip_532.wav and clip_572.wav
# Processing files: clip_533.wav and clip_573.wav
# Processing files: clip_534.wav and clip_574.wav
# Processing files: clip_535.wav and clip_575.wav
# Processing files: clip_536.wav and clip_576.wav
# Processing files: clip_537.wav and clip_577.wav
# Processing files: clip_538.wav and clip_578.wav
# Processing files: clip_539.wav and clip_579.wav
# Processing files: clip_54.wav and clip_58.wav
# Processing files: clip_540.wav and clip_580.wav
# Processing files: clip_541.wav and clip_581.wav
# Processing files: clip_542.wav and clip_582.wav
# Processing files: clip_543.wav and clip_583.wav
# Processing files: clip_544.wav and clip_584.wav
# Processing files: clip_545.wav and clip_585.wav
# Processing files: clip_546.wav and clip_586.wav
# Processing files: clip_547.wav and clip_587.wav
# Processing files: clip_548.wav and clip_588.wav
# Processing files: clip_549.wav and clip_589.wav
# Processing files: clip_55.wav and clip_59.wav
# Processing files: clip_550.wav and clip_590.wav
# Processing files: clip_551.wav and clip_591.wav
# Processing files: clip_552.wav and clip_592.wav
# Processing files: clip_553.wav and clip_593.wav
# Processing files: clip_554.wav and clip_594.wav
# Processing files: clip_555.wav and clip_595.wav
# Processing files: clip_556.wav and clip_596.wav
# Processing files: clip_557.wav and clip_597.wav
# Processing files: clip_558.wav and clip_598.wav
# Processing files: clip_559.wav and clip_599.wav
# Processing files: clip_56.wav and clip_6.wav
# Processing files: clip_560.wav and clip_60.wav
# Processing files: clip_561.wav and clip_600.wav
# Processing files: clip_562.wav and clip_601.wav
# Processing files: clip_563.wav and clip_602.wav
# Processing files: clip_564.wav and clip_603.wav
# Processing files: clip_565.wav and clip_604.wav
# Processing files: clip_566.wav and clip_605.wav
# Processing files: clip_567.wav and clip_606.wav
# Processing files: clip_568.wav and clip_607.wav
# Processing files: clip_569.wav and clip_608.wav
# Processing files: clip_57.wav and clip_609.wav
# Processing files: clip_570.wav and clip_61.wav
# Processing files: clip_571.wav and clip_610.wav
# Processing files: clip_572.wav and clip_611.wav
# Processing files: clip_573.wav and clip_612.wav
# Processing files: clip_574.wav and clip_613.wav
# Processing files: clip_575.wav and clip_614.wav
# Processing files: clip_576.wav and clip_615.wav
# Processing files: clip_577.wav and clip_616.wav
# Processing files: clip_578.wav and clip_617.wav
# Processing files: clip_579.wav and clip_618.wav
# Processing files: clip_58.wav and clip_619.wav
# Processing files: clip_580.wav and clip_62.wav
# Processing files: clip_581.wav and clip_620.wav
# Processing files: clip_582.wav and clip_621.wav
# Processing files: clip_583.wav and clip_622.wav
# Processing files: clip_584.wav and clip_623.wav
# Processing files: clip_585.wav and clip_624.wav
# Processing files: clip_586.wav and clip_625.wav
# Processing files: clip_587.wav and clip_626.wav
# Processing files: clip_588.wav and clip_627.wav
# Processing files: clip_589.wav and clip_628.wav
# Processing files: clip_59.wav and clip_629.wav
# Processing files: clip_590.wav and clip_63.wav
# Processing files: clip_591.wav and clip_630.wav
# Processing files: clip_592.wav and clip_631.wav
# Processing files: clip_593.wav and clip_632.wav
# Processing files: clip_594.wav and clip_633.wav
# Processing files: clip_595.wav and clip_634.wav
# Processing files: clip_596.wav and clip_635.wav
# Processing files: clip_597.wav and clip_636.wav
# Processing files: clip_598.wav and clip_637.wav
# Processing files: clip_599.wav and clip_638.wav
# Processing files: clip_6.wav and clip_639.wav
# Processing files: clip_60.wav and clip_64.wav
# Processing files: clip_600.wav and clip_640.wav
# Processing files: clip_601.wav and clip_641.wav
# Processing files: clip_602.wav and clip_642.wav
# Processing files: clip_603.wav and clip_643.wav
# Processing files: clip_604.wav and clip_644.wav
# Processing files: clip_605.wav and clip_645.wav
# Processing files: clip_606.wav and clip_646.wav
# Processing files: clip_607.wav and clip_647.wav
# Processing files: clip_608.wav and clip_648.wav
# Processing files: clip_609.wav and clip_649.wav
# Processing files: clip_61.wav and clip_65.wav
# Processing files: clip_610.wav and clip_650.wav
# Processing files: clip_611.wav and clip_651.wav
# Processing files: clip_612.wav and clip_652.wav
# Processing files: clip_613.wav and clip_653.wav
# Processing files: clip_614.wav and clip_654.wav
# Processing files: clip_615.wav and clip_655.wav
# Processing files: clip_616.wav and clip_656.wav
# Processing files: clip_617.wav and clip_657.wav
# Processing files: clip_618.wav and clip_658.wav
# Processing files: clip_619.wav and clip_659.wav
# Processing files: clip_62.wav and clip_66.wav
# Processing files: clip_620.wav and clip_660.wav
# Processing files: clip_621.wav and clip_661.wav
# Processing files: clip_622.wav and clip_662.wav
# Processing files: clip_623.wav and clip_663.wav
# Processing files: clip_624.wav and clip_664.wav
# Processing files: clip_625.wav and clip_665.wav
# Processing files: clip_626.wav and clip_666.wav
# Processing files: clip_627.wav and clip_667.wav
# Processing files: clip_628.wav and clip_668.wav
# Processing files: clip_629.wav and clip_669.wav
# Processing files: clip_63.wav and clip_67.wav
# Processing files: clip_630.wav and clip_670.wav
# Processing files: clip_631.wav and clip_671.wav
# Processing files: clip_632.wav and clip_672.wav
# Processing files: clip_633.wav and clip_673.wav
# Processing files: clip_634.wav and clip_674.wav
# Processing files: clip_635.wav and clip_675.wav
# Processing files: clip_636.wav and clip_676.wav
# Processing files: clip_637.wav and clip_677.wav
# Processing files: clip_638.wav and clip_678.wav
# Processing files: clip_639.wav and clip_679.wav
# Processing files: clip_64.wav and clip_68.wav
# Processing files: clip_640.wav and clip_680.wav
# Processing files: clip_641.wav and clip_681.wav
# Processing files: clip_642.wav and clip_682.wav
# Processing files: clip_643.wav and clip_683.wav
# Processing files: clip_644.wav and clip_684.wav
# Processing files: clip_645.wav and clip_685.wav
# Processing files: clip_646.wav and clip_686.wav
# Processing files: clip_647.wav and clip_687.wav
# Processing files: clip_648.wav and clip_688.wav
# Processing files: clip_649.wav and clip_689.wav
# Processing files: clip_65.wav and clip_69.wav
# Processing files: clip_650.wav and clip_690.wav
# Processing files: clip_651.wav and clip_691.wav
# Processing files: clip_652.wav and clip_692.wav
# Processing files: clip_653.wav and clip_693.wav
# Processing files: clip_654.wav and clip_694.wav
# Processing files: clip_655.wav and clip_695.wav
# Processing files: clip_656.wav and clip_696.wav
# Processing files: clip_657.wav and clip_697.wav
# Processing files: clip_658.wav and clip_698.wav
# Processing files: clip_659.wav and clip_699.wav
# Processing files: clip_66.wav and clip_7.wav
# Processing files: clip_660.wav and clip_70.wav
# Processing files: clip_661.wav and clip_700.wav
# Processing files: clip_662.wav and clip_701.wav
# Processing files: clip_663.wav and clip_702.wav
# Processing files: clip_664.wav and clip_703.wav
# Processing files: clip_665.wav and clip_704.wav
# Processing files: clip_666.wav and clip_705.wav
# Processing files: clip_667.wav and clip_706.wav
# Processing files: clip_668.wav and clip_707.wav
# Processing files: clip_669.wav and clip_708.wav
# Processing files: clip_67.wav and clip_709.wav
# Processing files: clip_670.wav and clip_71.wav
# Processing files: clip_671.wav and clip_710.wav
# Processing files: clip_672.wav and clip_711.wav
# Processing files: clip_673.wav and clip_712.wav
# Processing files: clip_674.wav and clip_713.wav
# Processing files: clip_675.wav and clip_714.wav
# Processing files: clip_676.wav and clip_715.wav
# Processing files: clip_677.wav and clip_716.wav
# Processing files: clip_678.wav and clip_717.wav
# Processing files: clip_679.wav and clip_718.wav
# Processing files: clip_68.wav and clip_719.wav
# Processing files: clip_680.wav and clip_72.wav
# Processing files: clip_681.wav and clip_720.wav
# Processing files: clip_682.wav and clip_73.wav
# Processing files: clip_683.wav and clip_74.wav
# Processing files: clip_684.wav and clip_75.wav
# Processing files: clip_685.wav and clip_76.wav
# Processing files: clip_686.wav and clip_77.wav
# Processing files: clip_687.wav and clip_78.wav
# Processing files: clip_688.wav and clip_79.wav
# Processing files: clip_689.wav and clip_8.wav
# Processing files: clip_69.wav and clip_80.wav
# Processing files: clip_690.wav and clip_81.wav
# Processing files: clip_691.wav and clip_82.wav
# Processing files: clip_692.wav and clip_83.wav
# Processing files: clip_693.wav and clip_84.wav
# Processing files: clip_694.wav and clip_85.wav
# Processing files: clip_695.wav and clip_86.wav
# Processing files: clip_696.wav and clip_87.wav
# Processing files: clip_697.wav and clip_88.wav
# Processing files: clip_698.wav and clip_89.wav
# Processing files: clip_699.wav and clip_9.wav
# Processing files: clip_7.wav and clip_90.wav
# Processing files: clip_70.wav and clip_91.wav
# Processing files: clip_700.wav and clip_92.wav
# Processing files: clip_701.wav and clip_93.wav
# Processing files: clip_702.wav and clip_94.wav
# Processing files: clip_703.wav and clip_95.wav
# Processing files: clip_704.wav and clip_96.wav
# Processing files: clip_705.wav and clip_97.wav
# Processing files: clip_706.wav and clip_98.wav
# Processing files: clip_707.wav and clip_99.wav

# %% [markdown]
# ### Combining audio files for 3 different classes

# %%
# Setting input folders
folder_1_path = "data/sitar"
folder_2_path = "data/bansuri"
folder_3_path = "data/harmonium"

# Set the output folder
output_folder = "data/zTest_output_3"

# Get the list of files in each folder
files_1 = os.listdir(folder_1_path)
files_2 = os.listdir(folder_2_path)
files_3 = os.listdir(folder_3_path)

# Determine the minimum number of files in any folder
min_files = min(len(files_1), len(files_2), len(files_3))

# Set the desired duration for each clip (4 seconds in this case)
clip_duration = 4000  # in milliseconds

# Iterate through each set of audio clips in the folders
for i in range(1, min_files + 1):
    # Load the audio clips
    audio_1 = AudioSegment.from_file(f"{folder_1_path}/{files_1[i-1]}", format="wav")
    audio_2 = AudioSegment.from_file(f"{folder_2_path}/{files_2[i-1]}", format="wav")
    audio_3 = AudioSegment.from_file(f"{folder_3_path}/{files_3[i-1]}", format="wav")

    # Ensure all audio clips have the same duration (adjust if needed)
    min_length = min(len(audio_1), len(audio_2), len(audio_3), clip_duration)
    audio_1 = audio_1[:min_length]
    audio_2 = audio_2[:min_length]
    audio_3 = audio_3[:min_length]

    # Set the duration of each overlap (1 second in this case)
    overlap_duration = 1000  # in milliseconds

    # Initialize the combined audio with the first 4 seconds of the first clip
    combined_audio = audio_1[:clip_duration]

    # Iterate over the remaining duration and overlap the clips
    for t in range(clip_duration, min_length, overlap_duration):
        # Adjust the crossfade duration to ensure it doesn't exceed the remaining duration
        crossfade_duration = min(overlap_duration, min_length - t)

        combined_audio = combined_audio.append(
            audio_1[t:t + overlap_duration].crossfade(audio_2[t:t + overlap_duration], crossfade_duration)
            .crossfade(audio_3[t:t + overlap_duration], crossfade_duration)
        )

    # Export the combined audio clip
    combined_audio.export(f"{output_folder}/clip_{i}.wav", format="wav")

# %% [markdown]
# ### Combining audio files for 4 different classes

# %%
from pydub import AudioSegment
import os

# Replace these paths with the actual paths to your folders
folder_1_path = "data/harmonium"
folder_2_path = "data/bansuri"
folder_3_path = "data/sitar"
folder_4_path = "data/tabla"

# Set the output folder
output_folder = "output-sitar-tabla-harmonium-bansuri"

# Get the list of files in each folder
files_1 = os.listdir(folder_1_path)
files_2 = os.listdir(folder_2_path)
files_3 = os.listdir(folder_3_path)
files_4 = os.listdir(folder_4_path)

# Determine the minimum number of files in any folder
min_files = min(len(files_1), len(files_2), len(files_3), len(files_4))

# Set the desired duration for each clip (4 seconds in this case)
clip_duration = 4000  # in milliseconds

# Iterate through each set of audio clips in the folders
for i in range(1, min_files + 1):
    # Load the audio clips
    audio_1 = AudioSegment.from_file(f"{folder_1_path}/{files_1[i-1]}", format="wav")
    audio_2 = AudioSegment.from_file(f"{folder_2_path}/{files_2[i-1]}", format="wav")
    audio_3 = AudioSegment.from_file(f"{folder_3_path}/{files_3[i-1]}", format="wav")
    audio_4 = AudioSegment.from_file(f"{folder_4_path}/{files_4[i-1]}", format="wav")

    # Ensure all audio clips have the same duration (adjust if needed)
    min_length = min(len(audio_1), len(audio_2), len(audio_3), len(audio_4), clip_duration)
    audio_1 = audio_1[:min_length]
    audio_2 = audio_2[:min_length]
    audio_3 = audio_3[:min_length]
    audio_4 = audio_4[:min_length]

    # Set the duration of each overlap (1 second in this case)
    overlap_duration = 1000  # in milliseconds

    # Initialize the combined audio with the first 4 seconds of the first clip
    combined_audio = audio_1[:clip_duration]

    # Iterate over the remaining duration and overlap the clips
    for t in range(clip_duration, min_length, overlap_duration):
        # Adjust the crossfade duration to ensure it doesn't exceed the remaining duration
        crossfade_duration = min(overlap_duration, min_length - t)

        combined_audio = combined_audio.append(
            audio_1[t:t + overlap_duration].crossfade(audio_2[t:t + overlap_duration], crossfade_duration)
            .crossfade(audio_3[t:t + overlap_duration], crossfade_duration)
            .crossfade(audio_4[t:t + overlap_duration], crossfade_duration)
        )

    # Export the combined audio clip
    combined_audio.export(f"{output_folder}/clip_{i}.wav", format="wav")
